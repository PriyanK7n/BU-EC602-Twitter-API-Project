# %%
# Install snscrape
#!pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
# Importing required modules
import itertools
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
# Giving the list of terms to searched
search_terms = ["Help", "Earthquake", "India", " affected","dead", "rebuild", "emergency" "destroyed", "tragedy"]

# %%
# Creating the search string based on the search_terms.
search_string = ""

for i in range(len(search_terms)):
    if i!=len(search_terms)-1:
        search_term =search_terms[i]
        search_string += search_term + " OR "

search_string += search_terms[-1]

search_string
# Out:
# 'Help OR Earthquake OR India OR  affected OR dead OR rebuild OR emergencydestroyed OR tragedy'

# %%
# Creating a pandas dataframe with the extracted tweets
tweets_df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(search_string).get_items(), 10000))

# %%
# PATH to save the data
path = r"ENTER THE PATH"
tweets_df.to_pickle(path + "disaster" + ".pkl")

# %%
tweets_df.shape
# Out:
# (10000, 27)

# %%
tweets_df
# Out:
#                                                     url  \
# 0     https://twitter.com/MarthaCarnahan2/status/158...
# 1     https://twitter.com/GeauxTigahss/status/158164...
# 2     https://twitter.com/Cricketador/status/1581643...
# 3     https://twitter.com/lawk0502/status/1581643347...
# 4     https://twitter.com/talkybassist/status/158164...
# ...                                                 ...
# 9995  https://twitter.com/BuzzInshort/status/1581638...
# 9996  https://twitter.com/Viirenn_India/status/15816...
# 9997  https://twitter.com/Stevedalton57/status/15816...
# 9998  https://twitter.com/NiranjanEcsinf1/status/158...
# 9999  https://twitter.com/shpiirti/status/1581638899...
#
#                           date  \
# 0    2022-10-16 13:48:54+00:00
# 1    2022-10-16 13:48:54+00:00
# 2    2022-10-16 13:48:54+00:00
# 3    2022-10-16 13:48:54+00:00
# 4    2022-10-16 13:48:53+00:00
# ...                        ...
# 9995 2022-10-16 13:31:14+00:00
# 9996 2022-10-16 13:31:14+00:00
# 9997 2022-10-16 13:31:14+00:00
# 9998 2022-10-16 13:31:13+00:00
# 9999 2022-10-16 13:31:13+00:00
#
#                                                 content  \
# 0     @darla_tapp @Vol_Football Congratulations @dar...
# 1     @bigpeenboi3 @thtmfnoah @ninjaturtles383 @West...
# 2     @Mansoor_Ahmed76 @frank11285 And this excludes...
# 3     IDBI has a big contribution in the Indian econ...
# 4     Devil May Cry is better without you https://t....
# ...                                                 ...
# 9995  ⚡7 - NRIs ATTENTION! Five investment options t...
# 9996                                     @SDesh01 👍👍🤣🤣🤣
# 9997  @eamonlynch @golfweek Eamon can’t help but to ...
# 9998  India unlikely to be hit as hard by global rec...
# 9999  @bhuttercupss @MAMACITAMAYHEM @theboybarbie_ @...
#
#                                         renderedContent                   id  \
# 0     @darla_tapp @Vol_Football Congratulations @dar...  1581643350046052352
# 1     @bigpeenboi3 @thtmfnoah @ninjaturtles383 @West...  1581643348057919488
# 2     @Mansoor_Ahmed76 @frank11285 And this excludes...  1581643348011814912
# 3     IDBI has a big contribution in the Indian econ...  1581643347021946880
# 4     Devil May Cry is better without you twitter.co...  1581643346178498561
# ...                                                 ...                  ...
# 9995  ⚡7 - NRIs ATTENTION! Five investment options t...  1581638903831810049
# 9996                                     @SDesh01 👍👍🤣🤣🤣  1581638901420404741
# 9997  @eamonlynch @golfweek Eamon can’t help but to ...  1581638900862226433
# 9998  India unlikely to be hit as hard by global rec...  1581638899797200896
# 9999  @bhuttercupss @MAMACITAMAYHEM @theboybarbie_ @...  1581638899650424832
#
#                                                    user  replyCount  \
# 0     {'username': 'MarthaCarnahan2', 'id': 13085795...           0
# 1     {'username': 'GeauxTigahss', 'id': 294078525, ...           0
# 2     {'username': 'Cricketador', 'id': 145597499039...           0
# 3     {'username': 'lawk0502', 'id': 157863577479875...           0
# 4     {'username': 'talkybassist', 'id': 13038616667...           0
# ...                                                 ...         ...
# 9995  {'username': 'BuzzInshort', 'id': 149476436536...           1
# 9996  {'username': 'Viirenn_India', 'id': 1278968383...           0
# 9997  {'username': 'Stevedalton57', 'id': 2208940650...           0
# 9998  {'username': 'NiranjanEcsinf1', 'id': 13615737...           0
# 9999  {'username': 'shpiirti', 'id': 153636419056214...           2
#
#       retweetCount  likeCount  quoteCount  ...  \
# 0                0          0           0  ...
# 1                0          0           0  ...
# 2                0          0           0  ...
# 3                0          0           0  ...
# 4                0          0           0  ...
# ...            ...        ...         ...  ...
# 9995             0          0           0  ...
# 9996             0          0           0  ...
# 9997             0          0           0  ...
# 9998             0          0           0  ...
# 9999             0          0           0  ...
#
#                                                   media retweetedTweet  \
# 0                                                  None           None
# 1                                                  None           None
# 2                                                  None           None
# 3                                                  None           None
# 4                                                  None           None
# ...                                                 ...            ...
# 9995                                               None           None
# 9996                                               None           None
# 9997                                               None           None
# 9998  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 9999  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
#
#                                             quotedTweet inReplyToTweetId  \
# 0                                                  None     1.581437e+18
# 1                                                  None     1.581308e+18
# 2                                                  None     1.581643e+18
# 3                                                  None     1.581643e+18
# 4     {'url': 'https://twitter.com/PG_kamiya/status/...              NaN
# ...                                                 ...              ...
# 9995                                               None     1.581639e+18
# 9996                                               None     1.581628e+18
# 9997                                               None     1.581083e+18
# 9998                                               None              NaN
# 9999                                               None     1.581638e+18
#
#                                           inReplyToUser  \
# 0     {'username': 'darla_tapp', 'id': 2196965384, '...
# 1     {'username': 'bigpeenboi3', 'id': 139585921504...
# 2     {'username': 'Cricketador', 'id': 145597499039...
# 3     {'username': 'lawk0502', 'id': 157863577479875...
# 4                                                  None
# ...                                                 ...
# 9995  {'username': 'BuzzInshort', 'id': 149476436536...
# 9996  {'username': 'SDesh01', 'id': 1189881853676670...
# 9997  {'username': 'eamonlynch', 'id': 20702280, 'di...
# 9998                                               None
# 9999  {'username': 'bhuttercupss', 'id': 14266505136...
#
#                                          mentionedUsers coordinates place  \
# 0     [{'username': 'darla_tapp', 'id': 2196965384, ...        None  None
# 1     [{'username': 'bigpeenboi3', 'id': 13958592150...        None  None
# 2     [{'username': 'Mansoor_Ahmed76', 'id': 1509729...        None  None
# 3     [{'username': 'DFS_India', 'id': 9412227179439...        None  None
# 4                                                  None        None  None
# ...                                                 ...         ...   ...
# 9995                                               None        None  None
# 9996  [{'username': 'SDesh01', 'id': 118988185367667...        None  None
# 9997  [{'username': 'eamonlynch', 'id': 20702280, 'd...        None  None
# 9998                                               None        None  None
# 9999  [{'username': 'bhuttercupss', 'id': 1426650513...        None  None
#
#                                                hashtags cashtags
# 0                                                  None     None
# 1                                                  None     None
# 2                                                  None     None
# 3     [NobelAwardWinnersSaidGovtBankSavesNation, Sav...     None
# 4                                                  None     None
# ...                                                 ...      ...
# 9995  [internationalMonetaryFund, India, NRI, Person...     None
# 9996                                               None     None
# 9997                                               None     None
# 9998                                               None     None
# 9999                                               None     None
#
# [10000 rows x 27 columns]
