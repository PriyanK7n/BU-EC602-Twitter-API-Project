# %%
# Install snscrape
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /private/var/folders/k4/7jd9kc_d7wsg8rnpjrkhb2fc0000gn/T/pip-req-build-t1qevenw
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /private/var/folders/k4/7jd9kc_d7wsg8rnpjrkhb2fc0000gn/T/pip-req-build-t1qevenw
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 59abeaf04c38c85b3afed3fb6b907a6868019877
# ...

# %%
pip install snscrape
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 59 kB 849 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.6 MB 6.0 MB/s eta 0:00:01
# ...
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# ...
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# ...
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# ...
#   WARNING: The script snscrape is installed in '/Users/priyank/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.1.2; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing required modules
import itertools
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
# Giving the list of terms to searched
search_terms = ["disaster", "earthquake", "shake", "tremor", "Help", "save", "collapse","extraction"]

# %%
# Creating the search string based on the search_terms.
search_string = ""

for i in range(len(search_terms)):
    if i!=len(search_terms)-1:
        search_term =search_terms[i]
        search_string += search_term + " OR "

search_string += search_terms[-1]

search_string
# Out:
# 'disaster OR earthquake OR shake OR tremor OR Help OR save OR collapse OR extraction'

# %%
# Creating a pandas dataframe with the extracted tweets
tweets_df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(search_string).get_items(), 10000))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2b9470bbed72> in <module>
#       1 # Creating a pandas dataframe with the extracted tweets
# ----> 2 tweets_df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(search_string).get_items(), 10000))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     561         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     562             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 563                 data = list(data)
#     564             if len(data) > 0:
#     565                 if is_dataclass(data[0]):
#
# ~/Library/Python/3.8/lib/python/site-packages/snscrape/modules/twitter.py in get_items(self)
# ...

# %%
# PATH to save the data
path = r"ENTER THE PATH"
tweets_df.to_pickle(path + "earthqterms" + ".pkl")

# %%
tweets_df.shape

# %%
tweets_df
# Out:
#                                                    url  \
# 0    https://twitter.com/nainil/status/158164161817...
# 1    https://twitter.com/ErkSkittles/status/1581641...
# 2    https://twitter.com/SOLOCANSINGSONG/status/158...
# 3    https://twitter.com/Dimitri_payes/status/15816...
# 4    https://twitter.com/FatKidDeals/status/1581641...
# ..                                                 ...
# 995  https://twitter.com/mcnulty_salty/status/15816...
# 996  https://twitter.com/Yimmie_Egatz/status/158164...
# 997  https://twitter.com/bookkats/status/1581641086...
# 998  https://twitter.com/KMezzone/status/1581641085...
# 999  https://twitter.com/the_one_true_g/status/1581...
#
#                          date  \
# 0   2022-10-16 13:42:01+00:00
# 1   2022-10-16 13:42:01+00:00
# 2   2022-10-16 13:42:01+00:00
# 3   2022-10-16 13:42:01+00:00
# 4   2022-10-16 13:42:01+00:00
# ..                        ...
# 995 2022-10-16 13:39:55+00:00
# 996 2022-10-16 13:39:55+00:00
# ...
